# %% [markdown]
# # DATA ANALYTICS INTERN @ TECH-A-INTERN

# %% [markdown]
# ### AUTHOR : PARVEJ ALAM M. ANSARI

# %% [markdown]
# # TASK 4 : Movie Ratings Analysis

# %% [markdown]
# ### The dataset is available at Kaggle : https://www.kaggle.com/datasets/ayushimishra2809/movielens-dataset

# %% [markdown]
# ## About Movie Recommendation Dataset
#
# GroupLens Research has collected and made available rating data sets from the MovieLens web site (http://movielens.org). The data sets were collected over various periods of time, depending on the size of the set.

# %% [markdown]
# ### The data consists of 105339 ratings applied over 10329 movies.
#
# The movies.csv dataset contains three columns:
#
#  - movieId: the ID of the movie
#  - title: movies title
#  - genres: movies genres
#
# The ratings.csv dataset contains four columns:
#
#  - userId: the ID of the user who rated the movie.
#  - movieId: the ID of the movie
#  - ratings: ratings given by each user (from 0 to 5)
#  - Timstamp: The time the movie was rated.

# %% [markdown]
# ## Types of Recommendation System
#  - **Popularity Based**
#
# It keeps a track of view counts for each movie/video and then lists movies based on views in descending order.
#
#  - **Content Based**
#
# This type of recommendation systems, takes in a movie that a user currently likes as input. Then it analyzes the contents of the movie to find out other movies which have similar content. Then it ranks similar movies according to their similarity scores and recommends the most relevant movies to the user.
#
#  - **Collaborative Filtering**
#
# In other words, the recommendations get filtered based on the collaboration between similar user’s preferences.

# %% [markdown]
# In this notebook we are going to implement **Content Based Recommendation System**.

# %% [markdown]
# ## 1. Importing Required Libraries:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA):

# %%
# Loading Dataset:
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')

# %%
# Checking first five columns
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Checking shape of dataset
movies.shape
# Out:
# (10329, 3)

# %%
# Checking Datatype of features 
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10329 entries, 0 to 10328
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  10329 non-null  int64
#  1   title    10329 non-null  object
#  2   genres   10329 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 242.2+ KB

# %%
# Statistical summary:
movies.describe()
# Out:
#              movieId
# count   10329.000000
# mean    31924.282893
# std     37734.741149
# min         1.000000
# 25%      3240.000000
# 50%      7088.000000
# 75%     59900.000000
# max    149532.000000

# %%
# Checking first five columns
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       16     4.0  1217897793
# 1       1       24     1.5  1217895807
# 2       1       32     4.0  1217896246
# 3       1       47     4.0  1217896556
# 4       1       50     4.0  1217896523

# %%
# Checking shape of dataset
ratings.shape
# Out:
# (105339, 4)

# %%
# Checking Datatype of features
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105339 entries, 0 to 105338
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     105339 non-null  int64
#  1   movieId    105339 non-null  int64
#  2   rating     105339 non-null  float64
#  3   timestamp  105339 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.2 MB

# %%
# Statistical summary
ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  105339.000000  105339.000000  105339.000000  1.053390e+05
# mean      364.924539   13381.312477       3.516850  1.130424e+09
# std       197.486905   26170.456869       1.044872  1.802660e+08
# min         1.000000       1.000000       0.500000  8.285650e+08
# 25%       192.000000    1073.000000       3.000000  9.711008e+08
# 50%       383.000000    2497.000000       3.500000  1.115154e+09
# 75%       557.000000    5991.000000       4.000000  1.275496e+09
# max       668.000000  149532.000000       5.000000  1.452405e+09

# %% [markdown]
#  From the above table we can conclue that
#
#  - The average rating is 3.5 and minimum and maximum rating is 0.5 and 5 respectively.
#  - There are 668 user who has given their ratings for 149532 movies.

# %% [markdown]
# ## 3. Data Visualization and Preprocessing:

# %%
# Data cleaning:

genres = []
for genre in movies.genres:
    
    x = genre.split('|')
    for i in x:
         if i not in genres:
            genres.append(str(i))
genres = str(genres)    
movie_title = []
for title in movies.title:
    movie_title.append(title[0:-7])
movie_title = str(movie_title)

# %%
wordcloud_genre = WordCloud(width=1500,height=800,background_color='black',min_font_size=2
                    ,min_word_length=3).generate(genres)
wordcloud_title = WordCloud(width=1500,height=800,background_color='cyan',min_font_size=2
                    ,min_word_length=3).generate(movie_title)

# %%
# WORDCLOUD for Movies Genre
plt.figure(figsize=(15,10))
plt.axis('off')
plt.title('WORDCLOUD for Movies Genre',fontsize=15)
plt.imshow(wordcloud_genre)
plt.show()

# %%
# WORD CLOUD for Movies Title
plt.figure(figsize=(15,10))
plt.axis('off')
plt.title('WORD CLOUD for Movies Title',fontsize=15)
plt.imshow(wordcloud_title)
plt.show()

# %%
# Merging Movies and Ratings dataset:
df = pd.merge(ratings, movies, how='left',on='movieId')
df.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1       16     4.0  1217897793
# 1       1       24     1.5  1217895807
# 2       1       32     4.0  1217896246
# 3       1       47     4.0  1217896556
# 4       1       50     4.0  1217896523
#
#                                        title                   genres
# 0                              Casino (1995)              Crime|Drama
# 1                              Powder (1995)             Drama|Sci-Fi
# 2  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller
# 3                Seven (a.k.a. Se7en) (1995)         Mystery|Thriller
# 4                 Usual Suspects, The (1995)   Crime|Mystery|Thriller

# %%
# Checking Movies Ratings:
df1 = df.groupby(['title'])[['rating']].sum()
high_rated = df1.nlargest(20,'rating')
high_rated.head(10)
# Out:
#                                            rating
# title
# Shawshank Redemption, The (1994)           1372.0
# Pulp Fiction (1994)                        1352.0
# Forrest Gump (1994)                        1287.0
# Silence of the Lambs, The (1991)           1216.5
# Star Wars: Episode IV - A New Hope (1977)  1143.5
# Matrix, The (1999)                         1113.0
# Jurassic Park (1993)                       1076.0
# Schindler's List (1993)                    1065.5
# Braveheart (1995)                          1019.0
# Terminator 2: Judgment Day (1991)          1002.0

# %%
# Top 20 movies with the average rating

# Calculate the average rating for each movie
average_ratings = df.groupby('title')['rating'].mean()

# Select the top 20 movies with the highest average ratings
top_20_average_movies = average_ratings.nlargest(20)

plt.figure(figsize=(30, 10))
plt.title('Top 20 movies with the average rating', fontsize=40)
colors = ['red', 'yellow', 'orange', 'green', 'magenta', 'cyan', 'blue', 'lightgreen', 'skyblue', 'purple']
plt.ylabel('Average Rating', fontsize=30)
plt.xticks(range(len(top_20_average_movies.index)), top_20_average_movies.index, fontsize=18, rotation=90)  # Increase font size
plt.xlabel('Movie Title', fontsize=30)
plt.yticks(fontsize=25)
plt.bar(range(len(top_20_average_movies.index)), top_20_average_movies, linewidth=3, edgecolor='red', color=colors)
plt.show()

# %%
# Top 20 movies with highest rating
plt.figure(figsize=(30,10))
plt.title('Top 20 movies with highest rating',fontsize=40)
colors=['red','yellow','orange','green','magenta','cyan','blue','lightgreen','skyblue','purple']
plt.ylabel('ratings',fontsize=30)
plt.xticks(fontsize=25,rotation=90)
plt.xlabel('movies title',fontsize=30)
plt.yticks(fontsize=25)
plt.bar(high_rated.index,high_rated['rating'],linewidth=3,edgecolor='red',color=colors)
plt.show()

# %%
df2 = df.groupby('title')[['rating']].count()
rating_count_20 = df2.nlargest(20,'rating')
rating_count_20.head(10)
# Out:
#                                            rating
# title
# Pulp Fiction (1994)                           325
# Forrest Gump (1994)                           311
# Shawshank Redemption, The (1994)              308
# Jurassic Park (1993)                          294
# Silence of the Lambs, The (1991)              290
# Star Wars: Episode IV - A New Hope (1977)     273
# Matrix, The (1999)                            261
# Terminator 2: Judgment Day (1991)             253
# Braveheart (1995)                             248
# Schindler's List (1993)                       248

# %%
# Top 20 movies with highest number of ratings
plt.figure(figsize=(30,10))
plt.title('Top 20 movies with highest number of ratings',fontsize=30)
plt.xticks(fontsize=25,rotation=90)
plt.yticks(fontsize=25)
plt.xlabel('movies title',fontsize=30)
plt.ylabel('ratings',fontsize=30)

plt.bar(rating_count_20.index,rating_count_20.rating,color='red')
plt.show()

# %%
# Movie Ratings Distribution
plt.figure(figsize=(12, 6))
plt.hist(df['rating'], bins=5, color='skyblue', edgecolor='black')
plt.title('Movie Ratings Distribution', fontsize=16)
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Number of Movies', fontsize=12)
plt.show()

# %%
# Movies Genre Distribution
# Assuming the 'genres' column is formatted as a list of genres for each movie
genres_count = df['genres'].str.split('|').explode().value_counts()
plt.figure(figsize=(12, 6))
genres_count.plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Genre Distribution', fontsize=16)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Number of Movies', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# Release Year Distribution
df['release_year'] = pd.to_datetime(df['timestamp'], unit='s').dt.year
plt.figure(figsize=(12, 6))
plt.hist(df['release_year'], bins=30, color='orange', edgecolor='black')
plt.title('Movie Release Year Distribution', fontsize=16)
plt.xlabel('Release Year', fontsize=12)
plt.ylabel('Number of Movies', fontsize=12)
plt.show()

# %%
# Movie Ratings Over Time
# Assuming you have a 'timestamp' column indicating the release date
df['release_year'] = pd.to_datetime(df['timestamp'], unit='s').dt.year
average_ratings_over_time = df.groupby('release_year')['rating'].mean()

plt.figure(figsize=(12, 6))
plt.plot(average_ratings_over_time.index, average_ratings_over_time.values, marker='o', color='blue')
plt.title('Average Movie Ratings Over Time', fontsize=16)
plt.xlabel('Release Year', fontsize=12)
plt.ylabel('Average Rating', fontsize=12)
plt.grid()
plt.show()

# %%
# Top 5 Highest Rated Genres

# Split the 'genres' column to create separate rows for each genre
df['genres'] = df['genres'].str.split('|')
df = df.explode('genres')

# Calculate the average rating for each genre
average_ratings_by_genre = df.groupby('genres')['rating'].mean()

# Select the top 5 genres with the highest average ratings
top_5_genres = average_ratings_by_genre.nlargest(5)

# Create a bar plot for the top 5 genres
plt.figure(figsize=(12, 6))
top_5_genres.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Top 5 Highest Rated Genres', fontsize=16)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Average Rating', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# Ratings Distribution by Top 10 Genres

# Split the 'genres' column to create separate rows for each genre
df['genres'] = df['genres'].str.split('|')
df = df.explode('genres')

# Calculate the average rating for each genre
average_ratings_by_genre = df.groupby('genres')['rating'].mean()

# Select the top 5 genres with the highest average ratings
top_10_genres = average_ratings_by_genre.nlargest(10)

# Filter the dataset to include only the top 5 genres
df_filtered = df[df['genres'].isin(top_10_genres.index)]

# Create a new DataFrame for the box plot
boxplot_data = [df_filtered[df_filtered['genres'] == genre]['rating'] for genre in top_10_genres.index]

# Create the box plot for the top 10 genres
plt.figure(figsize=(12, 6))
plt.xticks(rotation=45)
plt.boxplot(boxplot_data, labels=top_10_genres.index, vert=False, showfliers=False)
plt.title('Ratings Distribution by Top 10 Genres', fontsize=16)
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Genre', fontsize=12)
plt.show()

# %%
cv = TfidfVectorizer()
tfidf_matrix = cv.fit_transform(movies['genres'])

# %%
movie_user = df.pivot_table(index='userId',columns='title',values='rating')
movie_user.head()
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Til There Was You (1997)  'burbs, The (1989)  \
# userId
# 1                          NaN                        NaN                 NaN
# 2                          NaN                        NaN                 NaN
# 3                          NaN                        NaN                 NaN
# 4                          NaN                        NaN                 NaN
# 5                          NaN                        NaN                 NaN
#
# title   'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# ...

# %% [markdown]
# Suppose a user wants to watch a movie similar to Toy Story (1995) then we can recommend the user by calculating the cosine similarity between Toy Story and other movies. So we have to first find the cosine similarity betw

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
indices = pd.Series(movies.index,index=movies['title'])
titles = movies['title']
def recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:21]
    movie_indices = [i[0] for i in sim_scores]
    return titles.iloc[movie_indices]

# %% [markdown]
# ## Suggesting Similar Type of Movie based upon Content:

# %%
# Example_1:

recommended_movies = recommendations('Matrix, The (1999)')
# Create a bar plot to display the top 10 recommended movies
plt.figure(figsize=(12, 6))
plt.barh(recommended_movies, np.arange(len(recommended_movies)), color='skyblue')
plt.xlabel('Similarity Score', fontsize=12)
plt.ylabel('Recommended Movies', fontsize=12)
plt.title('Top 10 Recommended Movies', fontsize=16)
plt.gca().invert_yaxis()  # Reverse the order to show the most similar first
plt.show()

# %%
# Example_2:

recommended_movies = recommendations('Braveheart (1995)')
# Create a bar plot to display the top 10 recommended movies
plt.figure(figsize=(12, 6))
plt.barh(recommended_movies, np.arange(len(recommended_movies)), color='skyblue')
plt.xlabel('Similarity Score', fontsize=12)
plt.ylabel('Recommended Movies', fontsize=12)
plt.title('Top 10 Recommended Movies', fontsize=16)
plt.gca().invert_yaxis()  # Reverse the order to show the most similar first
plt.show()

# %%
# Example_3:

recommended_movies = recommendations('Godfather, The (1972)')
# Create a bar plot to display the top 10 recommended movies
plt.figure(figsize=(12, 6))
plt.barh(recommended_movies, np.arange(len(recommended_movies)), color='skyblue')
plt.xlabel('Similarity Score', fontsize=12)
plt.ylabel('Recommended Movies', fontsize=12)
plt.title('Top 10 Recommended Movies', fontsize=16)
plt.gca().invert_yaxis()  # Reverse the order to show the most similar first
plt.show()

# %% [markdown]
# <p style="background-color:#F1C40F;color:black;font-size:22px;text-align:center;border-radius:10px 10px;font-weight:bold;border:2px solid #F1C40F;">Thank you😄!!!!!!</p>
